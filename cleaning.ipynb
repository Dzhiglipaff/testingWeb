# %%
import pandas as pd
df = pd.read_csv("DragonBites.txt",sep=",") #Creates a dataframe from the text file

#Removes the columns that are not needed for the database
df.drop(columns=["Timestamp","Explain why you gave this rating. What makes it what you gave it?","Anything else"], inplace=True)
print(df.to_string())
# Out:
#    Which restaurant are you rating?  Rate this restaurant!
# 0                Landmark Americana                      4
# 1                      Urban Eatery                      3
# 2                          Chipotle                      5
# 3                      Urban Eatery                      2
# 4                       Chick-Fil-A                      4
# 5                         Wild Blue                      3
# 6                          Chipotle                      4
# 7                          Chipotle                      1
# 8                    Sabrina's Cafe                      4
# 9                      Tataki Ramen                      4
# 10                      Chick-Fil-A                      4
# 11                     Urban Eatery                      3
# 12                     Tataki Ramen                      5
# 13                      Chick-Fil-A                      5
# 14                   Sabrina's Cafe                      5
# ...

# %%
#Saves the cleaned dataframe to a new csv file
df.to_csv("DragonBitesCleaned.csv", index=False)
